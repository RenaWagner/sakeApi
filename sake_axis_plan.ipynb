# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Single sake info

# %%
url = "https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/"
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:55.0) Gecko/20100101 Firefox/55.0',
}
req = requests.get(url, headers=headers)
soup = BeautifulSoup(req.text, 'html.parser').body
product_info = soup.find('div',attrs = {'class','product-info'})
print(product_info.prettify())
# Out:
# <div class="product-info summary col-fit col entry-summary product-summary">
#  <nav class="woocommerce-breadcrumb breadcrumbs">
#   <a href="https://sake.axisplan.com">
#    Home
#   </a>
#   <span class="divider">
#    /
#   </span>
#   <a href="https://sake.axisplan.com/product-category/sake/">
#    SAKE
#   </a>
#   <span class="divider">
#    /
#   </span>
#   <a href="https://sake.axisplan.com/product-category/sake/yucho-shuzo/">
#    Yucho Shuzo
#   </a>
#  </nav>
#  <h1 class="product-title product_title entry-title">
#   ALPHA KAZE NO MORI TYPE3
#  </h1>
#  <div class="is-divider small">
#  </div>
#  <ul class="next-prev-thumbs is-small show-for-medium">
#   <li class="prod-dropdown has-dropdown">
#    <a class="button icon is-outline circle" href="https://sake.axisplan.com/product/takacho-bodaimoto/" rel="next">
#     <i class="icon-angle-left">
#     </i>
#    </a>
#    <div class="nav-dropdown">
#     <a href="https://sake.axisplan.com/product/takacho-bodaimoto/" title="TAKACHO BODAIMOTO">
#      <img alt="Taka Chou Bodaimoto" class="attachment-shop_thumbnail size-shop_thumbnail wp-post-image" height="100" loading="lazy" sizes="(max-width: 100px) 100vw, 100px" src="https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-100x100.jpg" srcset="https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-100x100.jpg 100w, https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-400x400.jpg 400w, https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-280x280.jpg 280w, https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-768x768.jpg 768w, https://sake.axisplan.com/wp-content/uploads/2019/11/takacho-510x510.jpg 510w, https://sake.axisplan.com/wp-content/uploads/2019/11/takacho.jpg 800w" width="100"/>
#     </a>
#    </div>
#   </li>
#  </ul>
#  <div class="product-short-description">
#   <p>
#    <strong>
#     TYPE
#    </strong>
#    : Junmai Daiginjo
#    <br/>
#    <strong>
#     ALC(VOL.):
#    </strong>
#    14.0%
#    <br/>
#    <strong>
#     RICE
#    </strong>
#    : Akitsuho
#    <br/>
#    <strong>
#     RICE MILLING
#    </strong>
#    : 50%
#   </p>
#   <p>
#    <a class="button primary is-bevel" href="https://sake.axisplan.com/sake-map/?sku=212173" rel="noopener" style="width:190px;" target="_blank">
#     <br/>
#     <span>
#      where to buy
#     </span>
#     <br/>
#    </a>
#   </p>
#  </div>
#  <a class="button secondary is-bevel" href="https://sake.axisplan.com/contact/" style="width:190px;">
#   <span>
#    Contact us
#   </span>
#  </a>
#  <div class="product_meta">
#   <span class="sku_wrapper">
#    SKU:
#    <span class="sku">
#     (BC) +212173- 720ml x 12 btls / (AB) +819857 - 720ml x 12 btls
#    </span>
#   </span>
#   <span class="posted_in">
#    Category:
#    <a href="https://sake.axisplan.com/product-category/sake/yucho-shuzo/" rel="tag">
#     Yucho Shuzo
#    </a>
#   </span>
#   <span class="tagged_as">
#    Tags:
#    <a href="https://sake.axisplan.com/product-tag/akitsuho/" rel="tag">
#     Akitsuho
#    </a>
#    ,
#    <a href="https://sake.axisplan.com/product-tag/fruity/" rel="tag">
#     Fruity
#    </a>
#    ,
#    <a href="https://sake.axisplan.com/product-tag/junmai-daiginjo/" rel="tag">
#     Junmai Daiginjo
#    </a>
#   </span>
#  </div>
#  <div class="social-icons share-icons share-row relative icon-style-outline">
#   <a class="icon button circle is-outline tooltip whatsapp show-for-medium" data-action="share/whatsapp/share" href="whatsapp://send?text=ALPHA%20KAZE%20NO%20MORI%20TYPE3 - https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/" title="Share on WhatsApp">
#    <i class="icon-phone">
#    </i>
#   </a>
#   <a class="icon button circle is-outline tooltip facebook" data-label="Facebook" href="//www.facebook.com/sharer.php?u=https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/" onclick="window.open(this.href,this.title,'width=500,height=500,top=300px,left=300px');  return false;" rel="noopener noreferrer nofollow" target="_blank" title="Share on Facebook">
#    <i class="icon-facebook">
#    </i>
#   </a>
#   <a class="icon button circle is-outline tooltip twitter" href="//twitter.com/share?url=https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/" onclick="window.open(this.href,this.title,'width=500,height=500,top=300px,left=300px');  return false;" rel="noopener noreferrer nofollow" target="_blank" title="Share on Twitter">
#    <i class="icon-twitter">
#    </i>
#   </a>
#   <a class="icon button circle is-outline tooltip email" href="/cdn-cgi/l/email-protection#" rel="nofollow" title="Email to a Friend">
#    <i class="icon-envelop">
#    </i>
#   </a>
#   <a class="icon button circle is-outline tooltip pinterest" href="//pinterest.com/pin/create/button/?url=https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/&amp;media=https://sake.axisplan.com/wp-content/uploads/2018/10/alpha3_800-800x800.jpg&amp;description=ALPHA%20KAZE%20NO%20MORI%20TYPE3" onclick="window.open(this.href,this.title,'width=500,height=500,top=300px,left=300px');  return false;" rel="noopener noreferrer nofollow" target="_blank" title="Pin on Pinterest">
#    <i class="icon-pinterest">
#    </i>
#   </a>
#  </div>
# </div>

# %%
def get_sake_details(url):
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser').body
    product_info = soup.find('div',attrs = {'class','product-info'})
    sake_details = {"title": product_info.find(class_="product-title").contents[0],
                    "type": product_info.find(class_="product-short-description").contents[1].contents[1],
                    "rice": product_info.find(class_="product-short-description").contents[1].contents[9],
                    "polish_percentage": product_info.find(class_="product-short-description").contents[1].contents[13],
                    "alcohol": product_info.find(class_="product-short-description").contents[1].contents[5],
                   }
    
    
    return sake_details
get_sake_details(url)
# Out:
# {'title': '\n\tALPHA KAZE NO MORI TYPE3',
#  'type': ': Junmai Daiginjo',
#  'rice': ': Akitsuho',
#  'polish_percentage': ': 50%',
#  'alcohol': '\xa014.0%'}

# %% [markdown]
# ## Get all urls

# %%
global_url = "https://sake.axisplan.com/sake-list/"
global_req = requests.get(global_url, headers=headers)
global_soup = BeautifulSoup(global_req.text, 'html.parser').body

# %%
single_box = global_soup.find(class_="product-small box")
print(single_box.prettify())
# Out:
# <div class="product-small box">
#  <div class="box-image">
#   <div class="image-fade_in_back">
#    <a href="https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/">
#     <img alt="Kazeno Mori Alpha 3" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/10/alpha3_800-247x296.jpg" width="247"/>
#    </a>
#   </div>
#   <div class="image-tools is-small top right show-on-hover">
#   </div>
#   <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#   </div>
#   <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#    <a class="quick-view" data-prod="2711" href="#quick-view">
#     Quick View
#    </a>
#   </div>
#  </div>
#  <!-- box-image -->
#  <div class="box-text text-center box-text-products">
#   <div class="title-wrapper">
#    <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#     Yucho Shuzo
#    </p>
#    <p class="name product-title">
#     <a href="https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/">
#      ALPHA KAZE NO MORI TYPE3
#     </a>
#    </p>
#   </div>
#  </div>
#  <!-- box-text -->
# </div>

# %%
single_url = single_box.a['href']
single_url
# Out:
# 'https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/'

# %%
def get_url(single_box):
    single_url = single_box.a['href']
    return single_url
get_url(single_box)
# Out:
# 'https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/'

# %%
all_single_boxes = global_soup.find_all("div", {"class": "product-small box"})
all_single_boxes
# Out:
# [<div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/">
#  <img alt="Kazeno Mori Alpha 3" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/10/alpha3_800-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="2711" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Yucho Shuzo		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/">ALPHA KAZE NO MORI TYPE3</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/tomio-zenryo-yamadanishiki/">
#  <img alt="Tomio Zenryo Yamadanishiki 1800" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/10/zenryoYamada_1800-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="2713" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Kitagawahonke		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/tomio-zenryo-yamadanishiki/">TOMIO ZENRYO YAMADANISHIKI</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/tomio-yamadanishiki49/">
#  <img alt="Tomio Yamadanishiki 49 720" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/10/tomio49_720-247x296.jpg" width="247"/><img alt="Tomio Yamadanishiki 49 1800" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/10/tomio49_1800-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="2714" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Kitagawahonke		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/tomio-yamadanishiki49/">TOMIO JDG YAMADA NISHIKI 49</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/ichigin/">
#  <img alt="Ichigin 720" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/ichigin720_800-1-247x296.jpg" width="247"/><img alt="Ichigin 1800" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/ichigin1800_800-1-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="761" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Saito Shuzo		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/ichigin/">ICHIGIN</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/izutsuyaihei-iwaimai35/">
#  <img alt="Izutsuya Ihei 35" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/izutsuya35_720_800-247x296.jpg" width="247"/><img alt="Izutsuya Ihei 35" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/IzutsuyaIhei35_1800-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="764" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Saito Shuzo		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/izutsuyaihei-iwaimai35/">IZUTSUYAIHEI IWAIMAI 35%</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/suiten-ippeki/">
#  <img alt="Suiten Ippeki" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/suiten_800-247x296.jpg" width="247"/><img alt="Suiten Ippeki Label" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/suitenIppekiLabel-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="588" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Saito Shuzo		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/suiten-ippeki/">SUITEN IPPEKI</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/izutsuya-ihei/">
#  <img alt="Izutsuya Ihei" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/izutsuya720_800-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="767" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Saito Shuzo		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/izutsuya-ihei/">IZUTSUYA IHEI</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/ichiro/">
#  <img alt="Ichiro" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/ichiro720_800-247x296.jpg" width="247"/><img alt="ICHIRO" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/02/ichiro-main-3-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="755" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			Dewazakura		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/ichiro/">ICHIRO</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product
class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2017/12/yuzusshu-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="792" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			CHOYA		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/yuzusshu/">YUZUSSHU</a></p></div> </div><!-- box-text -->
#  </div>,
#  <div class="product-small box">
#  <div class="box-image">
#  <div class="image-fade_in_back">
#  <a href="https://sake.axisplan.com/product/choya-original-sparkling/">
#  <img alt="CHOYA ORIGINAL SPARKLING" class="attachment-woocommerce_thumbnail size-woocommerce_thumbnail" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/11/choyaOroginalSparkling-247x296.jpg" width="247"/><img alt="choya Original Sparkling 187" class="show-on-hover absolute fill hide-for-small back-image" height="296" loading="lazy" src="https://sake.axisplan.com/wp-content/uploads/2018/11/choyaSparklingWine187-247x296.jpg" width="247"/> </a>
#  </div>
#  <div class="image-tools is-small top right show-on-hover">
#  </div>
#  <div class="image-tools is-small hide-for-small bottom left show-on-hover">
#  </div>
#  <div class="image-tools grid-tools text-center hide-for-small bottom hover-slide-in show-on-hover">
#  <a class="quick-view" data-prod="2885" href="#quick-view">Quick View</a> </div>
#  </div><!-- box-image -->
#  <div class="box-text text-center box-text-products">
#  <div class="title-wrapper"> <p class="category uppercase is-smaller no-text-overflow product-cat op-7">
#  			CHOYA		</p>
#  <p class="name product-title"><a href="https://sake.axisplan.com/product/choya-original-sparkling/">CHOYA ORIGINAL SPARKLING</a></p></div> </div><!-- box-text -->
#  </div>]

# %%
all_urls = [get_url(single_box) for single_box in all_single_boxes]
all_urls
# Out:
# ['https://sake.axisplan.com/product/alpha-kaze-no-mori-type3/',
#  'https://sake.axisplan.com/product/tomio-zenryo-yamadanishiki/',
#  'https://sake.axisplan.com/product/tomio-yamadanishiki49/',
#  'https://sake.axisplan.com/product/ichigin/',
#  'https://sake.axisplan.com/product/izutsuyaihei-iwaimai35/',
#  'https://sake.axisplan.com/product/suiten-ippeki/',
#  'https://sake.axisplan.com/product/izutsuya-ihei/',
#  'https://sake.axisplan.com/product/ichiro/',
#  'https://sake.axisplan.com/product/aiyama/',
#  'https://sake.axisplan.com/product/kotosennen-junmaidaiginjo/',
#  'https://sake.axisplan.com/product/junmai-daiginjo300/',
#  'https://sake.axisplan.com/product/junmai-daiginjo-genshu/',
#  'https://sake.axisplan.com/product/koi/',
#  'https://sake.axisplan.com/product/yukimegami48/',
#  'https://sake.axisplan.com/product/yukimegami35/',
#  'https://sake.axisplan.com/product/tomio-jdg-genshu-tobindori/',
#  'https://sake.axisplan.com/product/tomio-yamadanishiki/',
#  'https://sake.axisplan.com/product/yuki-manman-5years/',
#  'https://sake.axisplan.com/product/yuki-manman/',
#  'https://sake.axisplan.com/product/dewazakura-daiginjo/',
#  'https://sake.axisplan.com/product/kotosennen-junmaiginjo/',
#  'https://sake.axisplan.com/product/dewa-sansan/',
#  'https://sake.axisplan.com/product/omachi-junmai-ginjo/',
#  'https://sake.axisplan.com/product/tomio-tanshuyamadanishiki/',
#  'https://sake.axisplan.com/product/oka/',
#  'https://sake.axisplan.com/product/otaka/',
#  'https://sake.axisplan.com/product/kotosennen-junmai/',
#  'https://sake.axisplan.com/product/dewanosato/',
#  'https://sake.axisplan.com/product/takacho-bodaimoto/',
#  'https://sake.axisplan.com/product/ima/',
#  'https://sake.axisplan.com/product/white-cloudy-junmai/',
#  'https://sake.axisplan.com/product/black-super-dry/',
#  'https://sake.axisplan.com/product/karesansui-10years/',
#  'https://sake.axisplan.com/product/ml-hakko/',
#  'https://sake.axisplan.com/product/yous-time/',
#  'https://sake.axisplan.com/product/sweeeeet-kijoshu/',
#  'https://sake.axisplan.com/product/hannari-kyo-umeshu/',
#  'https://sake.axisplan.com/product/nigori-yuzu-umeshu/',
#  'https://sake.axisplan.com/product/hannari-shochu/',
#  'https://sake.axisplan.com/product/onikoroshi/',
#  'https://sake.axisplan.com/product/saku/',
#  'https://sake.axisplan.com/product/dewazakura-awasake/',
#  'https://sake.axisplan.com/product/tobiroku-nigori-sparkling/',
#  'https://sake.axisplan.com/product/tobiroku-nigori-sparkling/',
#  'https://sake.axisplan.com/product/nigori-yuzu-umeshu/',
#  'https://sake.axisplan.com/product/white-cloudy-junmai/',
#  'https://sake.axisplan.com/product/hannari-shochu/',
#  'https://sake.axisplan.com/product/kirishima_shochu_kuro/',
#  'https://sake.axisplan.com/product/kirishima_shochu_aka/',
#  'https://sake.axisplan.com/product/choya-23/',
#  'https://sake.axisplan.com/product/choya-yuzu/',
#  'https://sake.axisplan.com/product/choya-honkaku-umeshu/',
#  'https://sake.axisplan.com/product/choya-gold-edition/',
#  'https://sake.axisplan.com/product/ujigreentea/',
#  'https://sake.axisplan.com/product/juku-rich/',
#  'https://sake.axisplan.com/product/umehonori/',
#  'https://sake.axisplan.com/product/sarari-yuzu/',
#  'https://sake.axisplan.com/product/kokuto-umeshu/',
#  'https://sake.axisplan.com/product/soda-umesshu/',
#  'https://sake.axisplan.com/product/sarari-sparkling/',
#  'https://sake.axisplan.com/product/yuzusshu/',
#  'https://sake.axisplan.com/product/choya-original-sparkling/']

# %%
all_products_info = [get_sake_details(url) for url in all_urls]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/b0/_d1qk9tj0795kkpym61lkzmh0000gn/T/ipykernel_45142/3099293979.py in <module>
# ----> 1 all_products_info = [get_sake_details(url) for url in all_urls]
#
# /var/folders/b0/_d1qk9tj0795kkpym61lkzmh0000gn/T/ipykernel_45142/3099293979.py in <listcomp>(.0)
# ----> 1 all_products_info = [get_sake_details(url) for url in all_urls]
#
# /var/folders/b0/_d1qk9tj0795kkpym61lkzmh0000gn/T/ipykernel_45142/3799728186.py in get_sake_details(url)
#       5     sake_details = {"title": product_info.find(class_="product-title").contents[0],
#       6                     "type": product_info.find(class_="product-short-description").contents[1].contents[1],
# ----> 7                     "rice": product_info.find(class_="product-short-description").contents[1].contents[9],
#       8                     "polish_percentage": product_info.find(class_="product-short-description").contents[1].contents[13],
#       9                     "alcohol": product_info.find(class_="product-short-description").contents[1].contents[5],
#
# IndexError: list index out of range
